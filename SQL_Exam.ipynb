# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # SQL Exam
# © ExploreAI Academy

# %% [markdown]
# ## Instructions to students
#
# This challenge is designed to determine how much you have learned so far and will test your knowledge on SQL.
#
# The answers for this challenge should be selected on Athena for each corresponding multiple-choice question. The questions are included in this notebook and are numbered according to the Athena questions. The options for each question have also been included.
#
# Do not add or remove cells in this notebook. Do not edit or remove the `%%sql` comment as it is required to run each cell.
#
# **_Good luck!_**

# %% [markdown]
# ## Honour code
#
# I, YOUR NAME YOUR SURNAME, confirm – by submitting this document – that the solutions in this notebook are a result of my own work and that I abide by the EDSA honour code (https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.

# %% [markdown]
# ## The TMDb database
#
# In this supplementary exam, you will be exploring [The Movie Database](https://www.themoviedb.org/) – an online movie and TV show database that houses some of the most popular movies and TV shows at your fingertips. The TMDb database supports 39 official languages used in over 180 countries daily and dates back all the way to 2008.
#
#
# <img src="https://github.com/Explore-AI/Pictures/blob/master/sql_tmdb.jpg?raw=true" width=80%/>
#
#
# Below is an Entity Relationship Diagram (ERD) of the TMDb database:
#
# <img src="https://github.com/Explore-AI/Pictures/blob/master/TMDB_ER_diagram.png?raw=true" width=70%/>
#
# As can be seen from the ERD, the TMDb database consists of `12 tables` containing information about movies, cast, genre, and so much more.
#
# Let's get started!

# %% [markdown]
# ## Loading the database
#
# Before you begin, you need to prepare your SQL environment.  You can do this by loading the magic command `%load_ext sql`.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %% [markdown]
# Next, go ahead and load your database. To do this, you will need to ensure you have downloaded the `TMDB.db` sqlite file from Athena and have stored it in a known location.

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql sqlite:///TMDB-a-4006.db

# %% [markdown]
# If the above line didn't throw out any errors, then you should be good to go. Good luck with the exam!

# %% [markdown]
# ## Questions on SQL
#
# Use the given cell below each question to execute your SQL queries to find the correct input from the options provided. Your solution should match one of the multiple-choice questions on Athena.

# %% [markdown]
# ### Question 1
#
# Who won the Oscar for “Actor in a Leading Role” in  2015?
#
# (Hint: The winner is indicated as '1.0'.)
#
# **Options:**
#
#   - Micheal Fassbender
#   - Natalie Portman
#   - Leonardo DiCaprio
#   - Eddie Redmayne

# %%
# %%sql
# SELECT * FROM oscars WHERE year = 2015 AND winner = 1.0 AND award = "Actor in a Leading Role"
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('2015', 'Actor in a Leading Role', '1.0', 'Leonardo DiCaprio', 'The Revenant')]

# %% [markdown]
# ### Question 2
#
# What query will produce the ten oldest movies in the database?
#
# **Options:**
#
#  - SELECT TOP(10) * FROM movies WHERE release_date ORDER BY release_date ASC
#
#  - SELECT  * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date ASC LIMIT 10
#
#  - SELECT * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date DESC LIMIT 10
#
#  -  SELECT * FROM movies WHERE release_date IS NULL ORDER BY release_date DESC LIMIT 10

# %%
# %%sql
# SELECT * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date ASC LIMIT 10
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(3059, 'Intolerance', '1916-09-04 00:00:00.000000', 385907, None, 'en', 'Intolerance', 'The story of a poor young woman, separated by prejudice from her husband and baby, is interwoven with tales of intolerance from throughout history.', 3.232447, 8394751.0, 197.0, 'Released', 'The Cruel Hand of Intolerance', 7.4, 60),
#  (3060, 'The Big Parade', '1925-11-05 00:00:00.000000', 245000, None, 'en', 'The Big Parade', "The story of an idle rich boy who joins the US Army's Rainbow Division and is sent to France to fight in World War I, becomes friends with two working class men, experiences the horrors of trench warfare, and finds love with a French girl.", 0.785744, 22000000.0, 151.0, 'Released', None, 7.0, 21),
#  (19, 'Metropolis', '1927-01-10 00:00:00.000000', 92620000, None, 'de', 'Metropolis', "In a futuristic city sharply divided between the working class and the city planners, the son of the city's mastermind falls in love with a working class prophet who predicts the coming of a savior to mediate their differences.", 32.351527, 650422.0, 153.0, 'Released', 'There can be no understanding between the hands and the brain unless the heart acts as mediator.', 8.0, 657),
#  (905, "Pandora's Box", '1929-01-30 00:00:00.000000', 0, None, 'de', 'Die Bnchse der Pandora', 'The rise and inevitable fall of an amoral but naive young woman whose insouciant eroticism inspires lust and violence in those around her.', 1.824184, 0.0, 109.0, 'Released', None, 7.6, 45),
#  (65203, 'The Broadway Melody', '1929-02-08 00:00:00.000000', 379000, None, 'en', 'The Broadway Melody', "Harriet and Queenie Mahoney, a vaudeville act, come to Broadway, where their friend Eddie Kerns needs them for his number in one of Francis Zanfield' ... (195 characters truncated) ... eenie recognizes, that she is for Jock nothing more than a toy, and it also takes a while till Harriet recognizes, that Eddie is in love with Queenie", 0.968865, 4358000.0, 100.0, 'Released', "The pulsating drama of Broadway's bared heart speaks and sings with a voice to stir your soul!", 5.0, 19),
#  (22301, "Hell's Angels", '1930-11-15 00:00:00.000000', 3950000, None, 'en', "Hell's Angels", "Two brothers attending Oxford enlist with the Royal Flying Corps when World War I breaks out. Roy and Monte Rutledge have very different personalitie ... (576 characters truncated) ... t a strategic German munitions facility is a booming success, but with a squadron of fighters bearing down on them afterwards, escape seems unlikely.", 8.484123, 8000000.0, 127.0, 'Released', "Howard Hughes' Thrilling Multi-Million Dollar Air Spectacle", 6.1, 19),
#  (22649, 'A Farewell to Arms', '1932-12-08 00:00:00.000000', 4, None, 'en', 'A Farewell to Arms', "British nurse Catherine Barkley (Helen Hayes) and American Lieutenant Frederic Henry (Gary Cooper) fall in love during the First World War in Italy.  ... (105 characters truncated) ... the war rages on. Academy Awards winner for Best Cinematography and for Best Sound, Recording. Nominated for Best Picture and for Best Art Direction.", 1.199451, 25.0, 89.0, 'Released', 'Every woman who has loved will understand', 6.2, 28),
#  (3062, '42nd Street', '1933-02-02 00:00:00.000000', 439000, None, 'en', '42nd Street', 'A producer puts on what may be his last Broadway show, and at the last moment a chorus girl has to replace the star.', 1.933366, 2281000.0, 89.0, 'Released', None, 6.1, 37),
#  (43595, 'She Done Him Wrong', '1933-02-09 00:00:00.000000', 200000, None, 'en', 'She Done Him Wrong', '"New York singer and nightclub owner Lady Lou has more men friends than you can imagine. Unfortunately one of them is a vicious criminal who\'s escap ... (52 characters truncated) ... ing she hasn\'t exactly been faithful in his absence. Help is at hand in the form of young Captain Cummings a local temperance league leader though."', 0.622752, 2200000.0, 66.0, 'Released', "Mae West gives a 'Hot Time' to the nation!", 5.1, 27),
#  (3078, 'It Happened One Night', '1934-02-22 00:00:00.000000', 325000, None, 'en', 'It Happened One Night', "Ellie Andrews has just tied the knot with society aviator King Westley when she is whisked away to her father's yacht and out of King's clutches. Ell ... (233 characters truncated) ... ts her back to her husband, or he'll blow the whistle on Ellie to her father. Either way, Peter gets what he wants... a really juicy newspaper story!", 11.871424, 4500000.0, 105.0, 'Released', 'TOGETHER... for the first time', 7.7, 275)]

# %% [markdown]
# ### Question 3
#
# How many unique awards are there in the Oscars table?
#
# **Options:**
#  - 141
#  - 53
#  - 80
#  - 114

# %%
# %%sql
# SELECT COUNT(DISTINCT award) FROM Oscars
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(114,)]

# %% [markdown]
# ### Question 4
#
# How many movies are there that contain the word “Spider” within their title?
#
# **Options:**
#  - 0
#  - 5
#  - 1
#  - 9

# %%
# %%sql
# SELECT COUNT(title) FROM movies WHERE title LIKE "%Spider%"
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(9,)]

# %% [markdown]
# ### Question 5
#
# How many movies are there that are both in the "Thriller" genre and contain the word “love” anywhere in the keywords?
#
#
# **Options:**
#  - 48
#  - 38
#  - 14
#  - 1

# %%
# %%sql
# SELECT
#     -- movies.title,
#     -- genres.genre_name,
#     -- keywords.keyword_name
#     COUNT(DISTINCT movies.title)
# FROM
#     movies
# INNER JOIN
#     genremap ON movies.movie_id = genremap.movie_id
# INNER JOIN
#     keywordmap ON movies.movie_id = keywordmap.movie_id
# INNER JOIN
#     keywords ON keywordmap.keyword_id = keywords.keyword_id
# INNER JOIN
#     genres ON genremap.genre_id = genres.genre_id
# WHERE
#     genres.genre_name = "Thriller"
#     AND keywords.keyword_name LIKE "%love%"
# ORDER BY
#     movies.title
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(48,)]

# %% [markdown]
# ### Question 6
#
# How many movies are there that were released between 1 August 2006 ('2006-08-01') and 1 October 2009 ('2009-10-01') that have a popularity score of more than 40 and a budget of less than 50 000 000?
#
#
# **Options:**
#
#  - 29
#  - 23
#  - 28
#  - 35

# %%
# %%sql
# SELECT
#     /*title,
#     budget,
#     popularity*/
#     COUNT(*)
# FROM
#     movies
# WHERE
#     release_date BETWEEN '2006-08-01' AND '2009-10-01'
#     AND popularity > 40
#     AND budget < 50000000
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(29,)]

# %% [markdown]
# ### Question 7
#
# How many unique characters has "Vin Diesel" played so far in the database?
#
# **Options:**
#  - 24
#  - 19
#  - 18
#  - 16

# %%
# %%sql
# SELECT
#    COUNT(DISTINCT casts.characters) AS vin_diesel_character
# FROM
#     casts
# INNER JOIN actors
#     ON casts.actor_id = actors.actor_id
# WHERE
#     actors.actor_name = "Vin Diesel"
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(16,)]

# %% [markdown]
# ### Question 8
#
# What are the genres of the movie “The Royal Tenenbaums”?
#
#
# **Options:**
#  - Action, Romance
#  - Drama, Comedy
#  - Crime, Thriller
#  - Drama, Romance

# %%
# %%sql
# SELECT
#     movies.title,
#     genres.genre_name
# FROM
#     movies
# INNER JOIN
#     genremap ON movies.movie_id = genremap.movie_id
# INNER JOIN
#     genres ON genremap.genre_id = genres.genre_id
# WHERE
#     movies.title = "The Royal Tenenbaums"
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('The Royal Tenenbaums', 'Drama'), ('The Royal Tenenbaums', 'Comedy')]

# %% [markdown]
# ### Question 9
#
# What are the three production companies that have the highest movie popularity score on average, as recorded within the database?
#
#
# **Options:**
#
#  - MCL Films S.A., Turner Pictures, and George Stevens Productions
#  - The Donners' Company, Bulletproof Cupid, and Kinberg Genre
#  - Bulletproof Cupid, The Donners' Company, and MCL Films S.A
#  - B.Sting Entertainment, Illumination Pictures, and Aztec Musique

# %%
# %%sql
# SELECT
#     productioncompanies.production_company_name,
#     AVG(movies.popularity) AS avg_popularity_for_companies
# FROM
#     productioncompanies
# INNER JOIN
#     productioncompanymap ON productioncompanies.production_company_id = productioncompanymap.production_company_id
# INNER JOIN
#     movies ON productioncompanymap.movie_id = movies.movie_id
# GROUP BY
#     productioncompanies.production_company_name
# ORDER BY
#     avg_popularity_for_companies DESC
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [("The Donners' Company", 514.569956),
#  ('Bulletproof Cupid', 481.098624),
#  ('Kinberg Genre', 326.92099900000005),
#  ('Illumination Entertainment', 234.9200424),
#  ('Vita-Ray Dutch Productions (III)', 198.372395),
#  ('Deluxe Digital Studios', 198.372395),
#  ('Syncopy', 192.4171875),
#  ('Lynda Obst Productions', 192.22636225),
#  ('Cruel & Unusual Films', 155.790452),
#  ('Linson Films', 146.757391),
#  ('Knickerbocker Films', 146.757391),
#  ('Atman Entertainment', 146.757391),
#  ('Bristol Automotive', 145.364591),
#  ('Alfran Productions', 143.659698),
#  ('Artemple - Hollywood', 143.041543),
#  ('Second Mate Productions', 142.46499699999998),
#  ('Marvel Studios', 134.58636030769233),
#  ('Prime Focus', 134.279229),
#  ('Skydance Media', 133.69777399999998),
#  ('A113', 130.311355),
#  ('Fantasy Films', 127.525581),
#  ('Twilight Productions', 127.084938),
#  ('Fuji Television Network', 124.34186483333333),
#  ('The Saul Zaentz Company', 122.482275),
#  ('3Foot7', 120.965743),
#  ('Marvel Entertainment', 120.96049450000001),
#  ('Ian Bryce Productions', 116.840296),
#  ('Ollin Studio', 116.700319),
#  ('Babieka', 115.95539099999999),
#  ('China Movie Channel', 115.68126649999999),
#  ('Patalex III Productions Limited', 115.040024),
#  ('Odin', 114.522237),
#  ('Pit Bull Productions', 109.684788),
#  ('Imprint Entertainment', 109.65685599999999),
#  ('B24', 107.376788),
#  ('QuTbec Production Services Tax Credit', 102.322217),
#  ('Colorado Office of Film, Television & Media', 102.322217),
#  ('Abu Dhabi Film Commission', 102.322217),
#  ('Moving Picture Company (MPC)', 101.97398141666666),
#  ('T2 Productions', 101.74155),
#  ('Patalex IV Productions Limited', 101.250416),
#  ('Two Flints', 100.876794),
#  ('Northern Lights Films', 100.876794),
#  ('Hong Kong Alpha Motion Pictures Co.', 100.635882),
#  ('Esperanto Filmoj', 100.481513),
#  ('Vincent Newman Entertainment', 100.348805),
#  ('Slap Happy Productions (II)', 100.348805),
#  ('Canlaws Productions', 95.914473),
#  ('Mill Film', 95.301296),
#  ('Dawliz', 95.301296),
#  ('C & L', 95.301296),
#  ('M Productions', 95.223518),
#  ('Universal Pictures International (UPI)', 95.130041),
#  ('Fairview Entertainment', 94.199316),
#  ('Shaw Brothers', 94.056131),
#  ('Genre Films', 93.6588215),
#  ('Shamley Productions', 93.067866),
#  ('Chernin Entertainment', 92.51052657142858),
#  ('TSG Entertainment', 92.09418325925927),
#  ('Simon Kinberg Productions', 92.01899449999999),
#  ('Alpha Core', 92.01899449999999),
#  ('RatPac Entertainment', 91.4105815),
#  ('Legendary Pictures', 90.25522344117647),
#  ('Revolution Sun Studios', 89.79397637499999),
#  ('Matt Tolmach Productions', 89.270217),
#  ('Avi Arad Productions', 89.270217),
#  ('Kennedy Miller Productions', 89.1592947142857),
#  ('Taken 3', 88.844777),
#  ('Flynn Picture Company', 88.6273055),
#  ('8:38 Productions', 88.496873),
#  ('Sikelia Productions', 88.46131500000001),
#  ('Produzioni Europee Associati (PEA)', 88.377076),
#  ('Arturo Gonzßlez Producciones Cinematogrßficas S.A.', 88.377076),
#  ('Gotham Group', 88.29023466666666),
#  ('Mad Chance Productions', 87.53437),
#  ('22 & Indiana Pictures', 87.53437),
#  ('WingNut Films', 85.91749472727271),
#  ('Temple Hill Entertainment', 85.9064071),
#  ('Media Rights Capital (MRC)', 85.52836500000001),
#  ('Solipsist Film', 85.428395),
#  ('Residaco', 85.428395),
#  ('Heyday films', 85.30889633333334),
#  ('Fnnfte Babelsberg Film', 84.630969),
#  ('Mad Hatter Entertainment', 83.73858949999999),
#  ('LOVEFiLM International', 83.295796),
#  ('Lightstorm Entertainment', 83.1792138),
#  ('TC Productions', 83.05513533333334),
#  ('Pixar Animation Studios', 82.277073125),
#  ('IFP Westcoast Erste', 82.21166),
#  ('Allison Shearmur Productions', 82.0604755),
#  ('Sierra/Affinity', 82.052056),
#  ('2DUX¦', 81.834855),
#  ('Underworld Produktions GmbH', 81.829237),
#  ('Subterranean Productions UK Ltd.', 81.829237),
#  ('Subterranean Productions LLC', 81.829237),
#  ('Laurinfilm', 81.829237),
#  ('Museum Canada Productions', 81.781591),
#  ('Right of Way Films', 81.30552833333333),
#  ('Le Grisbi Productions', 81.23835125),
#  ('All Pictures Media', 80.879032),
#  ('Lonetree Entertainment', 79.922059),
#  ('Juno Pix', 79.579532),
#  ('Cecchi Gori Pictures', 79.579532),
#  ('Viz Media', 79.456485),
#  ('DC Entertainment', 79.28269225000001),
#  ('Dentsu', 79.06602816666667),
#  ('Universal Studios', 77.82189514285713),
#  ('Walt Disney Animation Studios', 76.96434625),
#  ('Captivate Entertainment', 76.489048),
#  ('Dayday Films', 76.455532),
#  ('Walt Disney Studios Motion Pictures', 75.46527316666668),
#  ('Heyday Films', 75.3502508),
#  ('Euro Film Funding', 74.234793),
#  ('China Film Co.', 74.23288466666666),
#  ('Mutant Enemy Productions', 73.987775),
#  ('Kemp Company', 73.944049),
#  ('Media Asia Group', 73.872343),
#  ('Five Drops', 73.872343),
#  ('Dreams of Dragon Picture', 73.872343),
#  ('Cloud Atlas Productions', 73.872343),
#  ('Ascension Pictures', 73.872343),
#  ('Top Cow Productions', 73.82289),
#  ('Ringerike Zweite Filmproduktion', 73.82289),
#  ('Kickstart Productions', 73.82289),
#  ('Sean Bailey Productions', 73.79505),
#  ('Prana Studios', 73.79505),
#  ('Victoires Productions', 73.720244),
#  ('Sofica Sofinergie 5', 73.720244),
#  ('MMC Independent', 73.720244),
#  ('Claudie Ossard Productions', 73.720244),
#  ('MavroCine Pictures GmbH & Co. KG', 73.616808),
#  ('The Turman-Morrissey Company', 73.567232),
#  ('Zehnte Babelsberg', 72.595961),
#  ('Visiona Romantica', 72.595961),
#  ('Crave Films', 72.332116),
#  ('Radical Studios', 72.2701255),
#  ('Beagle Pug Films', 71.96438549999999),
#  ('The Halcyon Company', 71.862892),
#  ('See Me Louisiana', 71.124686),
#  ('SOIXAN7E QUIN5E', 71.124686),
#  ('Heineken Branded Entertainment', 70.78591),
#  ('Maverick Films', 70.3511164),
#  ('warner bross Turkey', 68.794673),
#  ('Soho VFX', 68.794673),
#  ('A Band Apart', 68.582418),
#  ('Sierra / Affinity', 68.564919),
#  ('Pacific Standard', 68.08550066666668),
#  ('Black Bear Pictures', 67.79842066666667),
#  ('International Traders', 67.72996966666666),
#  ('Monolith Pictures (III)', 67.698004),
#  ('Robert Stigwood Organization (RSO)', 67.608041),
#  ('Panorama Films', 67.447636),
#  ("Loew's Incorporated", 67.417542),
#  ('DC Comics', 67.41039113333333),
#  ('Studio Ghibli', 67.20951099999999),
#  ('Color Force', 67.174350625),
#  ('Pacific Title and Art Studio', 67.169587),
#  ('Milk & Honey', 67.169587),
#  ('Linovo Productions GmbH & Co. KG', 67.169587),
#  ('Justin Pictures', 67.169587),
#  ('Red Wagon Entertainment', 67.08265371428571),
#  ('Down Productions', 66.94086466666667),
#  ('Dog Eat Dog Productions Inc.', 66.925866),
#  ('Helena Productions', 66.803149),
#  ('FortyFour Studios', 66.390712),
#  ('Pascal Pictures', 66.21806),
#  ('Ghostcorps', 66.21806),
#  ('Feigco Entertainment', 66.21806),
#  ('No Trace Camping', 66.11334),
#  ('Elevation Pictures', 66.11334),
#  ('Ronald Shusett/Gary Goldman', 65.948959),
#  ('Lucamar Productions', 65.90161),
#  ('Origo Film Group', 65.402595),
#  ('Giant Pictures', 65.402595),
#  ('Sneaky Shark', 65.352913),
#  ('Perfect Storm Entertainment', 65.352913),
#  ('Huahua Media', 65.352913),
#  ('RatPac-Dune Entertainment', 65.24772308333333),
#  ('Super Cool ManChu', 65.18878649999999),
#  ('Twickenham Film Studios', 64.782984),
#  ('Python (Monty) Pictures Limited', 64.782984),
#  ('National Film Trustee Company', 64.782984),
#  ('Michael White Productions', 64.782984),
#  ('LStar Capital', 64.55810533333333),
#  ('Adam Schroeder Productions', 64.504747),
#  ('SnowPiercer', 64.238688),
#  ('Opus Pictures', 64.238688),
#  ('Moho Film', 64.238688),
#  ('Hemisphere Media Capital', 64.07048950000001),
#  ('Blue Parrot Productions', 64.025031),
#  ('Latina Pictures', 63.721511),
#  ('Saw Productions Inc.', 63.655973),
#  ('Pendle Mountain Productions', 63.628459),
#  ('Jinks/Cohen Company', 63.5390435),
#  ('Noel Gay Motion Picture Company', 63.513324),
#  ('Blizzard Entertainment', 63.148529),
#  ('Alibaba Pictures Group', 63.148011333333336),
#  ('New Zealand Post Digital and Visual Effects Grant', 63.13678),
#  ('District 9', 63.13678),
#  ('Block / Hanson', 63.13678),
#  ('The Fourth Production Company Film Group', 63.079003),
#  ('MI 3 Film', 63.079003),
#  ('NeoReel', 62.93467999999999),
#  ('Keep Your Head', 62.933899),
#  ('Popaganda Films', 62.925175),
#  ('A&B Producoes', 62.925175),
#  ('MVL Incredible Productions', 62.898336),
#  ('Jerry Bruckheimer Films', 62.72836471428571),
#  ('Stephen J. Cannell Productions', 62.714026),
#  ('Wigram Productions', 62.692872333333334),
#  ('Mid Atlantic Films', 62.67791200000001),
#  ('Perfect World (Beijing) Pictures Co.', 62.641286),
#  ('QED International', 62.59198633333333),
#  ('RabbitBandini Productions', 62.554173),
#  ('Pop Films', 62.554173),
#  ("O' Salvation", 62.554173),
#  ('MJZ', 62.554173),
#  ('Iconoclast', 62.554173),
#  ('Division Films', 62.554173),
#  ('Parkes+MacDonald Image Nation', 62.30933725),
#  ('Nu Boyana Film Studios', 61.849521),
#  ('LHF Film', 61.849521),
#  ('Gerard Butler Alan Siegel Entertainment', 61.849521),
#  ('Crucial Films', 61.76233),
#  ('Broken Chair Flickz', 61.76233),
#  ('TF1', 61.58903599999999),
#  ('Traveling Picture Show Company (TPSC)', 61.309619),
#  ('Da Vinci Media Ventures', 61.309619),
#  ('Big Primate Pictures', 61.22601),
#  ('Spectrum Films', 61.196071),
#  ('A&E Television Networks', 61.196071),
#  ('TCF Vancouver Productions', 61.121717),
#  ('Ex3 Productions', 61.025639),
#  ('One Race Films', 60.923226),
#  ('Weimaraner Republic Pictures', 60.829621),
#  ('Bernd Eichinger Productions', 60.810723),
#  ('Nippon Television Network (NTV)', 60.732738),
#  ('Nibariki', 60.732738),
#  ('B.H. Finance C.V.', 60.722162),
#  ('I Remember Productions', 60.715151),
#  ('Ingenious Media', 60.560695571428575),
#  ('Cruel and Unusual Films', 60.269115000000006),
#  ('RVK Studios', 60.246978),
#  ('Newman/Tooley Films', 60.1018685),
#  ('Sommers Company, The', 60.034162),
#  ('Evergreen Media Group', 59.66510033333333),
#  ('Zaftig Films', 59.634029),
#  ('Warner Animation Group', 59.547928),
#  ('LEGO', 59.547928),
#  ('Truth Entertainment', 59.454473),
#  ('Orion-Nova Productions', 59.259204),
#  ('Skydance Productions', 58.888695299999995),
#  ('Italo/Judeo Productions', 58.845025),
#  ('Bill/Phillips', 58.845025),
#  ('Big Bug Pictures', 58.782359),
#  ('EMJAG Productions', 58.7559345),
#  ('Internationale Filmproduktion Eagle', 58.57976),
#  ('Geffen Company, The', 58.553213),
#  ('Atomic Monster', 58.4825905),
#  ('UW4 Productions', 58.401204),
#  ('Green Hat Films', 58.296856),
#  ('Laura Ziskin Productions', 58.1421068),
#  ('Bad Robot', 58.094266299999994),
#  ('Chartoff Winkler Productions', 57.773583),
#  ('Roth Films', 57.76374022222222),
#  ('Rena Film', 57.673932),
#  ('Peach Trees', 57.673932),
#  ('Red Granite Pictures', 57.655690250000006),
#  ('Sony Pictures Entertainment (SPE)', 57.566902999999996),
#  ('Kurtzman/Orci', 57.264993),
#  ('AR Films', 57.2506795),
#  ('Huayi Brothers Media', 57.20212775),
#  ('5150 Action', 57.167889),
#  ('CatchPlay', 57.135855),
#  ('October Pictures', 56.811056),
#  ('Fuzzy Door Productions', 56.806699333333334),
#  ("Ninjas Runnin' Wild Productions", 56.805781),
#  ('Covert Media', 56.805781),
#  ('Show East', 56.76349),
#  ('Egg Films', 56.76349),
#  ('GH Three', 56.758411),
#  ('Blue Light', 56.758411),
#  ('Oriental DreamWorks', 56.747978),
#  ('Annapurna Pictures', 56.673078333333336),
#  ('Brandywine Productions', 56.62573728571429),
#  ('Disney Double Dare You (DDY)', 56.523205),
#  ('Blue Sky Studios', 56.50474566666667),
#  ('Skylark Productions', 56.3804165),
#  ('White Noise Factory', 56.30466),
#  ('Dentsu Inc.', 56.30466),
#  ('Legend3D', 56.268916),
#  ('Pyramania', 56.257249),
#  ('Gordon Company', 56.16946333333334),
#  ('Grive Productions', 56.1559172),
#  ('Anarchos Productions', 56.003698),
#  ('Free State Pictures', 55.868832999999995),
#  ('Nimar Studios', 55.60012975000001),
#  ('Black Label Media', 55.424027),
#  ('Kontsept Film Company', 55.404327249999994),
#  ('Groucho II Film Partnership', 55.34013),
#  ('Perfect World Pictures', 55.3235775),
#  ('South Side Amusement Company', 55.249434),
#  ('Sketch Films', 55.1643375),
#  ('Munich Film Partners & Company (MFP) MI2 Productions', 54.931334),
#  ('Translux', 54.919835),
#  ('Electronic Arts', 54.81489),
#  ('Monarchy Enterprises S.a.r.l.', 54.808364),
#  ('Jaret Entertainment', 54.550275),
#  ('20th Century Fox Russia', 54.403033),
#  ('Peregrine', 54.121662),
#  ('Momentum Pictures', 54.053576),
#  ('Silverbell Films', 53.978602),
#  ('Propeler', 53.978602),
#  ('Ozumi Films', 53.978602),
#  ('Theobald Film Productions', 53.905592),
#  ('K/O Paper Products', 53.8741775),
#  ('Tonik Productions', 53.811461),
#  ('Asis Productions', 53.811461),
#  ('Spectrum Effects', 53.698683),
#  ('Hypnotic', 53.636249333333325),
#  ('Imaginary Forces', 53.54837800000001),
#  ('Platinum Dunes', 53.47686599999999),
#  ('TIK Films', 53.468325),
#  ('Motion Picture THETA Produktionsgesellschaft', 53.213931),
#  ('Point Grey Pictures', 53.055647),
#  ('Walt Disney Feature Animation', 53.055583222222225),
#  ('Indelible Productions', 53.043124),
#  ('Liberty Pictures', 52.792678),
#  ('Appian Way', 52.72684955555556),
#  ('Tequila Gang', 52.6858025),
#  ('Julia Phillips and Michael Phillips Productions', 52.456505),
#  ('Volcano Films', 52.449744),
#  ('OddLot Entertainment', 52.417529),
#  ('JHF Productions', 52.380982),
#  ('Cannell Studios', 52.380982),
#  ('33andOut Productions', 52.380982),
#  ('Hasbro', 52.36880466666667),
#  ('Animal Kingdom', 52.1723585),
#  ('Brownstone Productions', 52.12169),
#  ('Energy Entertainment', 51.938414),
#  ('UW3 Film Productions', 51.927471),
#  ('Filmtribe', 51.915025),
#  ('Hammer & Tongs', 51.742065),
#  ('1492 Pictures', 51.66617782352942),
#  ('Peninsula Films', 51.451719000000004),
#  ('Haishang Films', 51.328145),
#  ('The Body', 51.109279),
#  ('Act III', 51.109279),
#  ('Twentieth Century Fox Animation', 51.00923054545455),
#  ('Film 44', 51.006383),
#  ('Surf Film', 50.767332),
#  ('Enelmar Productions, A.I.E.', 50.767332),
#  ('Matten Productions', 50.7453),
#  ('Double Nickel Entertainment', 50.7453),
#  ('Hollywood Gang Productions', 50.716343),
#  ('Sunswept Entertainment', 50.626885500000014),
#  ('Lucasfilm', 50.59218426666668),
#  ('Telewizja Polska (TVP)', 50.587541),
#  ('Runteam', 50.587541),
#  ('Mainstream S.A.', 50.587541),
#  ('Heritage Films', 50.587541),
#  ('Filmboard Berlin-Brandenburg (FBB)', 50.587541),
#  ('FilmFernsehFonds Bayern', 50.587541),
#  ('Canal+Polska', 50.587541),
#  ('Agencja Produkcji Filmowej', 50.587541),
#  ('Constantin Film International', 50.561849),
#  ('Very Special Projects', 50.319662),
#  ('Pulse Films', 50.319662),
#  ('Mott Street Pictures', 50.319662),
#  ('Maiden Voyage Pictures', 50.319662),
#  ('Code Red Productions', 50.319662),
#  ('Dan Curtis Productions', 50.306728),
#  ('Zanuck Company, The', 50.153521500000004),
#  ('Hawk Films', 50.08003566666667),
#  ('Amercent Films', 50.009408),
#  ('Zoetrope Studios', 49.973462),
#  ('Bold Films', 49.892985499999995),
#  ('Hasbro Studios', 49.8165438),
#  ('Nu Boyana Viburno', 49.808505),
#  ('Shawn Danielle Productions Ltd.', 49.660055),
#  ('Peter Frankfurt Productions', 49.660055),
#  ('BillBlock Media', 49.6590385),
#  ('Film Department, The', 49.593978),
#  ('d-rights', 49.549984),
#  ('Tohokushinsha Film Corporation', 49.549984),
#  ('Buena Vista Home Entertainment', 49.549984),
#  ('Hedge Fund Film Partners', 49.517264),
#  ('Stanley Kubrick Productions', 49.368869999999994),
#  ('Rafran Cinematografica', 49.333137),
#  ('Finanzia San Marco', 49.333137),
#  ('Ludlum Entertainment', 49.297716),
#  ('Newbridge Film Capital', 49.294864),
#  ('DreamWorks Animation', 49.26717180645162),
#  ('Albert S. Ruddy Productions', 49.1800055),
#  ('Eidos Interactive', 49.1548435),
#  ('Inside Track 2', 49.12486),
#  ('De Wolfe Music', 49.12486),
#  ('Media Rights Capital', 49.054223916666665),
#  ('Silver Bullet Productions (II)', 49.046956),
#  ('Classic Media', 49.046956),
#  ('Blind Wink Productions', 49.046956),
#  ('Yuma', 48.801089),
#  ('Clarius Entertainment', 48.784734),
#  ('Stereo D', 48.775723),
#  ('The Coppola Company', 48.64311433333334),
#  ('Warner Bros. Pictures', 48.603545000000004),
#  ('U-Drive Productions', 48.597060000000006),
#  ('Ram Bergman Productions', 48.590583),
#  ('Shady Acres Entertainment', 48.56470233333332),
#  ('Overbrook Entertainment', 48.4592466),
#  ('Estudios Picasso', 48.409526),
#  ('CAMERON MACKINTOSH', 48.356214),
#  ('Stillking Films', 48.31544733333333),
#  ('New Line Productions', 48.170508),
#  ('Matter Productions', 48.170508),
#  ('Misha Films', 48.126297),
#  ('Berlanti Productions', 48.03528),
#  ('Silver State Production Services', 48.0343),
#  ('SJ Pictures', 48.0343),
#  ('SJ Heat Productions', 48.0343),
#  ('Cinema Seven Productions', 48.0343),
#  ('Vaughn Productions', 48.032734),
#  ('Tim Burton Productions', 47.91514408333333),
#  ('Producers Sales Organization', 47.862016),
#  ('Dieter Geissler Filmproduktion', 47.862016),
#  ('Bavaria Studios', 47.862016),
#  ('Cott Productions', 47.8474835),
#  ('Double Negative', 47.822557),
#  ('Act III Communications', 47.821445499999996),
#  ('WideAwake', 47.793294),
#  ('David Dobkin Productions', 47.753598),
#  ('Yellow Bird', 47.651083),
#  ('Ground Control', 47.651083),
#  ('Hoya Productions', 47.584643),
#  ('TF 1 Film Productions', 47.5612),
#  ('Mediaset Espa±a', 47.559928),
#  ('La Trini', 47.559928),
#  ('Institut Valencip de Cinematografia (IVAC)', 47.559928),
#  ('Generalitat Valenciana', 47.559928),
#  ('Apparatus Productions', 47.5518955),
#  ('Amblin Entertainment', 47.51972583673471),
#  ('Starlite Films', 47.479755),
#  ('Toma 78', 47.455148),
#  ('De Milo', 47.455148),
#  ('JD Productions', 47.436675),
#  ('See-Saw Films', 47.371001),
#  ('Bazmark Films', 47.22611275),
#  ('Junction Entertainment', 47.2150355),
#  ('Film Capital Europe Funds (FCEF )', 47.006162),
#  ('Knightsbridge Entertainment', 46.9976535),
#  ('Vengeance Productions Pty. Ltd.', 46.834704),
#  ('GH One', 46.834704),
#  ('Mediastream Vierte Film GmbH & Co. Vermarktungs KG', 46.794928000000006),
#  ('Mark Gordon Productions', 46.73035633333333),
#  ('Studio Babelsberg', 46.64621707692308),
#  ('Riddick Canada Productions', 46.630062),
#  ('WV Films II', 46.60109233333333),
#  ('Figment Films', 46.545087),
#  ('Smart Entertainment', 46.44812400000001),
#  ('DMG Entertainment', 46.29210166666667),
#  ('Filmgate Films', 46.2299625),
#  ('Key Creatives', 46.1969585),
#  ('Alberto Grimaldi Productions', 46.160048),
#  ('Xingu Films', 46.114184),
#  ('Lunar Industries', 46.114184),
#  ('Limelight Fund', 46.114184),
#  ('Liberty Films UK', 46.114184),
#  ('Permut Presentations', 46.075037),
#  ('Douglas/Reuther Productions', 46.075037),
#  ('SLM Production Group', 46.038449333333325),
#  ('Mostow/Lieberman Productions', 46.024482),
#  ('Taleswapper', 45.94834),
#  ('Digital Domain', 45.94834),
#  ('Chartoff Productions', 45.94834),
#  ('Inferno Distribution', 45.88498),
#  ('Outlaw Sinema', 45.8359835),
#  ('Trigger Street Productions', 45.74288133333334),
#  ('Zoom Hunt International Productions Company Ltd.', 45.742254),
#  ('United China Vision', 45.742254),
#  ('Asia Union Film & Entertainment Ltd.', 45.742254),
#  ('IAC Films', 45.742217),
#  ('Sony Pictures Imageworks (SPI)', 45.720894),
#  ('Rovio Mobile', 45.720894),
#  ('Rovio Entertainment', 45.720894),
#  ('Rovio Animation', 45.720894),
#  ('Parkes/MacDonald Productions', 45.638025714285725),
#  ('Watermark', 45.610993),
#  ('The Big Gun Project', 45.565918),
#  ('Little Wolf Entertainment', 45.565918),
#  ('Fox Family Films', 45.565918),
#  ('Unique Features', 45.514031),
#  ('Mr. Smith Productions', 45.514031),
#  ('American Empirical Pictures', 45.499573749999996),
#  ('British Film Council', 45.490374),
#  ('Eketahuna LLC', 45.477802),
#  ('Atmosphere Entertainment MM', 45.400827166666666),
#  ('Motion Picture BETA Produktionsgesellschaft', 45.381501),
#  ('Bourne Again', 45.381501),
#  ('Scholastic Entertainment', 45.351617),
#  ('SPD Films', 45.317278),
#  ('Farewell Productions', 45.274225),
#  ('MFPV Film', 45.1657085),
#  ('Runway Pictures Inc', 45.154631),
#  ('Kouf/Bigelow Productions', 45.154631),
#  ('Hiett Designs of Las Vegas', 45.154631),
#  ('Random Films', 45.151657),
#  ('Curse Productions', 45.083509),
#  ('Kennedy/Marshall Company, The', 45.06494241666667),
#  ('Osiris Films', 45.022964),
#  ('Katalyst Films', 45.000314),
#  ('Furia de Titanes II, A.I.E.', 44.927635),
#  ('Pink Machine', 44.906918),
#  ('Jeff Most Productions', 44.690107),
#  ('Entertainment Media Investment Corporation', 44.690107),
#  ('Crowvision Inc.', 44.690107),
#  ('Viacom Canada', 44.656151),
#  ('Cube Libre', 44.656151),
#  ('Blue Tulip Productions', 44.617481),
#  ('Cinema 84', 44.598211),
#  ('Mitsubishi', 44.568372),
#  ('The Princess Bride Ltd.', 44.533612),
#  ('Buttercup Films Ltd.', 44.533612),
#  ('New Amsterdam Entertainment', 44.529429),
#  ('Shark Productions', 44.511363),
#  ('Fear and Loathing LLC', 44.511363),
#  ('Reino del Cielo', 44.490453),
#  ('KOH', 44.490453),
#  ('Inside Track 3', 44.490453),
#  ('Calle Cruzada', 44.490453),
#  ('BK', 44.490453),
#  ('Boies / Schiller Film Group', 44.478043),
#  ('Pacific Data Images (PDI)', 44.466925999999994),
#  ('Fipex Holding', 44.4583255),
#  ('Infinitum Nihil', 44.43065725),
#  ('Lereby Productions', 44.356711),
#  ('Globo filmes', 44.356711),
#  ('Lawrence Gordon Productions', 44.20981400000001),
#  ('Marvel Enterprises', 44.185028375),
#  ('Riche-Ludwig Productions', 44.1778605),
#  ('Madhouse Entertainment', 44.145036),
#  ('Scared Productions', 44.094856),
#  ('Obelisk Productions', 43.873266),
#  ('Goldenlight Films', 43.791745),
#  ('Pontchartrain Productions', 43.753585),
#  ('Be Gentlemen Limited Partnership', 43.734886),
#  ('Into the Wild', 43.644978),
#  ('Will Vinton Studios', 43.571612),
#  ('Tim Burton Animation Company', 43.571612),
#  ('Atlas Entertainment', 43.534942),
#  ('Province of British Columbia Production Services Tax Credit', 43.512458),
#  ('Cloud Eight Films', 43.49025025),
#  ('Taurus Film', 43.3269116),
#  ('Opperman Viner Chrystyn Entertainment', 43.217089),
#  ('Hachiko', 43.217089),
#  ('Grand Army Entertainment', 43.217089),
#  ('Internationale Filmproduktion Stella-del-Sud Second', 43.192048),
#  ('Carolco International N.V.', 43.129703),
#  ('Scott Free Productions', 43.12422257142857),
#  ('Tree Line Films', 43.096013),
#  ('Sor Productions', 43.057323),
#  ('NEW Century', 43.057323),
#  ('M6', 43.05444266666666),
#  ('Danjaq', 43.03314337500001),
#  ('Scholastic Productions', 42.990906),
#  ('Bay Films', 42.9883975),
#  ('Why Not Productions', 42.9609998),
#  ('Lonlink Productions', 42.957216),
#  ('Kut Productions', 42.957216),
#  ('Charenton Productions Limited', 42.957216),
#  ('bob industries', 42.952942),
#  ('Walt Disney Pictures', 42.95151686842105),
#  ('Plan B Entertainment', 42.91454930769232),
#  ('Liberty Films (II)', 42.868495),
#  ('Cross Creek Pictures', 42.779147699999996),
#  ('Element Pictures', 42.7622405),
#  ('Mystery Clock Cinema', 42.758390999999996),
#  ('Village Roadshow Films North America', 42.741719),
#  ('Riche Productions', 42.741719),
#  ('Prime Universe Productions', 42.669304),
#  ('Daybreak Productions', 42.669304),
#  ('Anka Film', 42.669304),
#  ('H2S2 Filmproduktionsgesellschaft', 42.57877),
#  ('Etalon film', 42.538258),
#  ('Indochina Productions', 42.526405999999994),
#  ('Huayi Brothers Pictures', 42.512296),
#  ('Team Downey', 42.472324),
#  ('Angry Films', 42.3158605),
#  ('Saw 2 Productions', 42.187986),
#  ('Bluegrass Films', 42.16618871428572),
#  ('Zanuck/Brown Productions', 42.1111905),
#  ('GK Films', 42.0920964),
#  ('Limited Edition Productions Inc.', 42.006908),
#  ('Barry Mendel Productions', 41.91513260000001),
#  ('Earth Canada Productions', 41.890722),
#  ('Imhotep Productions', 41.862983),
#  ('Hughes Entertainment', 41.837306),
#  ('Wintergreen Productions', 41.81931185714285),
#  ('Lin Pictures', 41.6721178),
#  ('Paradise/MGN', 41.638961),
#  ('Feelgood Entertainment', 41.638961),
#  ('3DTK', 41.638961),
#  ('Evolution Entertainment', 41.60856575),
#  ('Thirteen Productions', 41.569541),
#  ('Michael De Luca Productions', 41.567586),
#  ('Disruption Entertainment', 41.534013),
#  ('Rocklin / Faust', 41.503588),
#  ('First Look Media', 41.503588),
#  ('Bad Hat Harry Productions', 41.49876758333333),
#  ('Summit Entertainment', 41.466143903846145),
#  ('C-2 Pictures', 41.4442875),
#  ('French Tax Credit', 41.426678),
#  ('Cineroma SRL', 41.426678),
#  ('Birnbaum/Barber', 41.426678),
#  ('Film 4', 41.3712565),
#  ('Swanford Films', 41.273567),
#  ('Reperage', 41.273567),
#  ('MP Film Management', 41.273567),
#  ('DOS', 41.273567),
#  ('Sony', 41.247402),
#  ('Laika Entertainment', 41.22826225),
#  ('No Such Productions', 41.207568),
#  ('Mark Canton Productions', 41.1975225),
#  ('Big Screen Productions', 41.17601130769231),
#  ('The Zanuck Company', 41.13147457142857),
#  ('Embassy International Pictures', 41.089863),
#  ('Moonrise', 41.083914),
#  ('Possessed Pictures', 41.045084),
#  ('Flower Films', 40.95946266666667),
#  ('Eon Productions', 40.874371090909094),
#  ('Darkwoods Productions', 40.75233949999999),
#  ('Todman, Simon, LeMasters Productions', 40.748915),
#  ('Sonnenfeld Josephson Worldwide Entertainment', 40.748915),
#  ('Belle Pictures', 40.721373),
#  ('Material Pictures', 40.702951),
#  ('Big Talk Productions', 40.70031060000001),
#  ('Lauren Levine Productions Inc.', 40.646102),
#  ('Hal Lieberman Company', 40.646102),
#  ('21 Laps Entertainment', 40.62294825),
#  ('Babelsberg Film', 40.61146425),
#  ('M6 Films', 40.591544125),
#  ('Rat Entertainment', 40.36191825),
#  ('Vast Entertainment', 40.28709),
#  ('Pt. Merantau Films', 40.285095),
#  ('Blumhouse Productions', 40.26209845454546),
#  ('Top Rope', 40.196514),
#  ('BrownHouse Productions', 40.176265),
#  ('Bottom of the Ninth Productions', 40.176265),
#  ('Reforma Films', 40.138009),
#  ('Moving Pictures', 40.137264),
#  ('Gratitude International', 40.137264),
#  ('Geisler-Roberdeau', 40.072583),
#  ('Syalis DA', 40.06688),
#  ('LTgende Entreprises', 40.06688),
#  ('Kalima Productions GmbH & Co. KG', 40.026951),
#  ('Sly Predator', 40.016306),
#  ('Matt Baer Films', 40.016306),
#  ('Lotus Entertainment (I)', 40.016306),
#  ('Gold Star Films', 40.016306),
#  ('Di Bonaventura Pictures', 39.937052210526325),
#  ('Brooksfilms Ltd.', 39.890798),
#  ('Virtual Studios', 39.87667714285715),
#  ('Gama Entertainment Partners', 39.873791),
#  ('Thunder Road Pictures', 39.869732625),
#  ('Daybreak', 39.784026),
#  ('Vendome Pictures', 39.777169),
#  ('Protozoa Pictures', 39.75137716666667),
#  ('VIP Medienfonds 4', 39.736673499999995),
#  ('Escape Artists', 39.73146876923077),
#  ('IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG', 39.6887954),
#  ('The Safran Company', 39.648703833333336),
#  ('Sony Pictures Animation', 39.60081508333334),
#  ('Walt Disney Company', 39.58676),
#  ('The Yomiuri Shimbun', 39.58676),
#  ('Taikei Office', 39.58676),
#  ('Lawson', 39.58676),
#  ('Asahi Soft Drinks Company', 39.58676),
#  ('DNA Films', 39.52485969999999),
#  ('Film Export A.G.', 39.511128),
#  ('Montecito Picture Company, The', 39.49664025),
#  ('Tokyo Movie Shinsha (TMS)', 39.338097),
#  ('TMS Entertainment', 39.338097),
#  ('Sumitomo Corporation', 39.338097),
#  ('Kodansha', 39.338097),
#  ('Akira Committee Company Ltd.', 39.338097),
#  ('Item 7', 39.337949),
#  ('Hofflund/Polone', 39.311698),
#  ('Ashton Productions', 39.30982),
#  ('Aldamisa Entertainment', 39.281839),
#  ('Big Kid Pictures', 39.279218666666665),
#  ('Demarest Films', 39.2410415),
#  ('Forward Pass', 39.1959915),
#  ('Goldmann Pictures', 39.151317666666664),
#  ('Lennox House Films', 39.127082),
#  ('BenderSpink', 39.02008766666667),
#  ('WR Universal Group', 39.019229),
#  ('Pacifica Film', 39.019229),
#  ('Mythology Entertainment (II)', 39.004588),
#  ('Crystal Sky Pictures', 38.998401333333334),
#  ('Overbrook Films', 38.994297),
#  ('Dune Entertainment', 38.89317925423729),
#  ('Achte Babelsberg Film', 38.832842),
#  ('Raw Nerve', 38.83192),
#  ('Hostel LLC', 38.83192),
#  ('ImageMovers', 38.817543444444446),
#  ('Decibel Films', 38.802415),
#  ('Ocean Films', 38.771062),
#  ('Jolly Film', 38.771062),
#  ('Classic Media Productions', 38.73494),
#  ('Bullwinkle Studios', 38.73494),
#  ('New Legacy', 38.6604345),
#  ('The Department of Trade and Industry of South Africa', 38.6595405),
#  ('Panda Productions Inc.', 38.643914),
#  ('Horticus UK', 38.643914),
#  ('Abraham Productions', 38.634767),
#  ('LBI Entertainment', 38.629763),
#  ('Yucaipa Films', 38.5729005),
#  ('Village Roadshow Pictures', 38.39371525925926),
#  ('Bandito Brothers', 38.386472499999996),
#  ('Nitrogen Studios Canada', 38.326835),
#  ('Anton Capital Entertainment (ACE)', 38.30587516666667),
#  ('Allegiance Theater', 38.279458),
#  ('Good Universe', 38.23130333333334),
#  ('Diamond Films', 38.179483),
#  ('Space Rocket Nation', 38.150787),
#  ('Amazon Studios', 38.150787),
#  ('Constantin Film.', 38.126095),
#  ('Pearl Street Films', 38.104794),
#  ('VH1 Television', 38.0958),
#  ('Tenth Planet Productions', 38.0958),
#  ('Red Hour Productions', 38.0958),
#  ('Motel Movies', 38.0882375),
#  ('Robert Wise Productions', 37.960289),
#  ('Argyle Enterprises', 37.960289),
#  ('Troublemaker Studios', 37.9406575),
#  ('Saints LA', 37.9230525),
#  ('Weed Road Pictures', 37.878450625),
#  ('Dark Horse Entertainment', 37.862490666666666),
#  ('Sony Pictures Releasing', 37.8049214),
#  ('Temple Hill Productions', 37.729059),
#  ('Prospect Park', 37.698465),
#  ('Millbrook Farm Productions', 37.698465),
#  ('Voltage Pictures', 37.670398),
#  ('Old Bull Pictures', 37.629309),
#  ('WeWork Studios', 37.555398),
#  ('Bersin Pictures', 37.555398),
#  ('Silver Pictures', 37.538289939393934),
#  ('World Wrestling Entertainment (WWE)', 37.537093),
#  ('Internationale Scarena Filmproduktionsgesellschaft 2', 37.492928),
#  ('Grosvenor Park Impact Productions', 37.378081),
#  ('Wardour Street Pictures', 37.195046),
#  ('The Mirisch Corporation', 37.1856435),
#  ('U.K. Tax Credit', 37.181019),
#  ('Poo Poo Pictures', 37.181019),
#  ('Parnassus Productions', 37.181019),
#  ('Movie Central', 37.181019),
#  ('British Columbia Film', 37.181019),
#  ('Straight Up Films', 37.1624815),
#  ('Bedlam Productions', 37.159547),
#  ('Amen Ra Films', 37.1409694),
#  ('Zide-Perry Productions', 37.132632),
#  ('Aperture Entertainment', 37.125349),
#  ('Kramer & Sigman Films', 37.1235905),
#  ('WV Films IV', 37.120677),
#  ('Spikings Entertainment', 37.084384),
#  ('Hollywood Studios International', 37.084384),
#  ('Herrick Entertainment', 37.084384),
#  ('Foresight Unlimited', 37.084384),
#  ('Los Hooligans Productions', 37.07600366666667),
#  ('K/O Camera Toys', 37.069253),
#  ('Contagious Entertainment', 36.960953),
#  ('The Complex Studio', 36.921445),
#  ('Jonathan Krane Group', 36.788745),
#  ('Aegis Film Fund', 36.732358500000004),
#  ('Finestkind', 36.670399),
#  ('Black and Blu Entertainment', 36.670399),
#  ('Top Shelf Productions', 36.664991),
#  ('Haunted Movies', 36.549589000000005),
#  ('Envision Entertainment Corporation', 36.48528533333333),
#  ('Verisimilitude', 36.4752635),
#  ('Jouer Limited', 36.444894),
#  ('Gruskoff/Venture Films', 36.444894),
#  ('Liveplanet', 36.432598),
#  ('M.G. Films', 36.423717),
#  ('Broadway Video', 36.423717),
#  ('Walt Disney Productions', 36.38208728571429),
#  ('Radical Media', 36.316527),
#  ('Warner Bros.', 36.247154263322884),
#  ('WV Films III', 36.205926),
#  ('Loumolo & Co.', 36.194802),
#  ('Zentropa International Sweden', 36.173598),
#  ('Zentropa International K÷ln', 36.173598),
#  ('Slot Machine', 36.173598),
#  ('Nordisk Film Distribution', 36.173598),
#  ('Legion Entertainment', 36.173598),
#  ('Edition Video', 36.173598),
#  ('Serendipity Productions', 36.133536),
#  ('Courtside Seats Productions', 36.125715),
#  ('Animal Logic', 36.05754175),
#  ('Marc Platt Productions', 35.969424000000004),
#  ('Chockstone Pictures', 35.91079775),
#  ('Extension 765', 35.897151),
#  ('MICA Entertainment', 35.871248),
#  ('Digital Image Associates', 35.797446666666666),
#  ('Inside Track Films', 35.781318),
#  ('Motion Picture Corporation of America (MPCA)', 35.777067),
#  ('A Grand Elephant', 35.754865),
#  ('Chambara Pictures', 35.720522),
#  ('Mandeville Films', 35.71795936363637),
#  ('Fellah Pictures', 35.695442),
#  ('Colombia Pictures', 35.695442),
#  ('Rosebud Productions', 35.674774),
#  ('Strike Entertainment', 35.60052457142857),
#  ('Catfish Productions', 35.580032),
#  ('Jerry Weintraub Productions', 35.566214124999995),
#  ('Farrell/Minoff', 35.537397),
#  ('Bungalow 78 Productions', 35.537397),
#  ('Jesse Films Inc.', 35.53352),
#  ('SkyLand Entertainment', 35.522027),
#  ('Parallel Zide', 35.5167795),
#  ('Shine Pictures', 35.481169),
#  ('Kudos Film and Television', 35.481169),
#  ('Section Eight', 35.453696375),
#  ('1984 Private Defense Contractors', 35.446817200000005),
#  ('Mike Zoss Productions', 35.440744625),
#  ('Misher Films', 35.39869816666666),
#  ('Hit & Run Productions', 35.387874),
#  ('Zippcast Films', 35.384423),
#  ('Orange Studios', 35.384423),
#  ('On Entertainment', 35.384423),
#  ('NetFlix', 35.384423),
#  ('CityMation', 35.384423),
#  ('Witness Protection Films', 35.350303),
#  ('BSM Studio', 35.307577),
#  ('EuropaCorp', 35.281137291666674),
#  ('Vendian Entertainment', 35.26336066666667),
#  ('ICF', 35.252056),
#  ('Maven Entertainment', 35.244037),
#  ('Lionsgate', 35.229539267857156),
#  ('National Film Development Corporation of India', 35.227212),
#  ('Indo-British', 35.227212),
#  ('Carolina Bank', 35.227212),
#  ('CinT+', 35.16422825),
#  ('Little Bird', 35.12936033333334),
#  ('The Shuman Company', 35.120736),
#  ('The Cantillon Company', 35.120736),
#  ('Don Carmody Productions', 35.04759975),
#  ('Radiant Productions', 35.003251999999996),
#  ('Village-A.M. Partnership', 34.973086),
#  ('Junger Witt Productions', 34.973086),
#  ('Coast Ridge', 34.973086),
#  ('A24', 34.94014444444444),
#  ('Wiedemann & Berg Filmproduktion', 34.938177),
#  ('Creado Film', 34.938177),
#  ('Valhalla Motion Pictures', 34.91808214285714),
#  ('Brood Syndicate', 34.917447),
#  ('B.D.S. Productions Inc.', 34.917447),
#  ('Cruise/Wagner Productions', 34.90522828571428),
#  ('KMP Film Invest', 34.8914405),
#  ('Chatrone', 34.890999),
#  ('Bagdasarian Productions', 34.871888),
#  ('Iron Horse Entertainment (II)', 34.854244),
#  ('Entertainment Manufacturing Company', 34.828241),
#  ('Copag V', 34.828241),
#  ('WT2 Productions', 34.7765485),
#  ('Sociedad General de Cine S.A.', 34.759855),
#  ('Koan Films', 34.759855),
#  ('Pacific Western', 34.593526),
#  ('Team Todd', 34.583011500000005),
#  ('Troika Pictures', 34.532418),
#  ('Emergency Films', 34.532418),
#  ('Apotheosis Media Group', 34.532418),
#  ('Amasia Entertainment', 34.532418),
#  ('LBI Productions', 34.519636),
#  ('Reliance Entertainment', 34.51063889999999),
#  ('Ingenious Film Partners', 34.496321034482754),
#  ('WCG Entertainment Productions', 34.4220725),
#  ('Hwy61', 34.421696),
#  ('FidTlitT Films', 34.421696),
#  ('Twisted Pictures', 34.38617),
#  ('Adam Fields Productions', 34.253237500000004),
#  ('Practical Pictures', 34.22565633333333),
#  ('Leverage Management', 34.2246425),
#  ('Film Colony', 34.160448),
#  ('Manhattan Project', 34.070054),
#  ('Illusion Entertainment', 34.052253),
#  ('Di Bonaventura Picture', 34.041407),
#  ('Cinema Group Ventures', 34.022209),
#  ('DumbDumb', 34.005726),
#  ('Aggregate Films', 34.005726),
#  ('Sycamore Pictures', 33.940064500000005),
#  ('New Crime Productions', 33.926473),
#  ('Mitteldeutsche Medienf÷rderung (MDM)', 33.923786),
#  ('Filmf÷rderanstalt (FFA)', 33.923786),
#  ('Twentieth Century Fox Film Corporation', 33.8508983108108),
#  ('Major Studio Partners', 33.814976200000004),
#  ('Industrial Light & Magic (ILM)', 33.769336),
#  ('Evil Twins', 33.7632695),
#  ('Dovemead Films', 33.728819333333334),
#  ('DW Studios', 33.704181),
#  ('Kinowelt Filmproduktion', 33.649652),
#  ('Karla Films', 33.649652),
#  ('First Light Production', 33.646355),
#  ('Survivor Productions', 33.625477),
#  ('Celador Films', 33.600997),
#  ('Goldcrest Pictures', 33.58323483333333),
#  ('Stan Winston Studio', 33.555764),
#  ('DCP Wrong Turn Productions', 33.555764),
#  ('ARD Degeto Film', 33.54393033333333),
#  ('Ehman Productions', 33.507289),
#  ('Penn Station Entertainment', 33.484027999999995),
#  ('Stoney Lake Entertainment', 33.452469),
#  ('Media Magik Entertainment', 33.4418695),
#  ('Marcy Media', 33.439187),
#  ('FilmNation Entertainment', 33.39685540000001),
#  ('Wonderland Sound and Vision', 33.3966255),
#  ('HorrorFlix', 33.394082),
#  ('River Road Entertainment', 33.388883),
#  ('Sunrise Entertainment (II)', 33.385429),
#  ('Biride Productions', 33.385429),
#  ('Hey Eddie', 33.323836666666665),
#  ('FilmDistrict', 33.32333),
#  ('HitRecord Films', 33.296684),
#  ('Loofah Productions', 33.238296),
#  ('Molinare Investment', 33.185328),
#  ('Nick Wechsler Productions', 33.180813),
#  ('Mad Max Films', 33.142185),
#  ('Crossroads', 33.142185),
#  ('American Entertainment Partners L.P.', 33.006683),
#  ('Centropolis Entertainment', 32.961967900000005),
#  ('Silent Hill DCP Inc.', 32.927994),
#  ('Konami', 32.927994),
#  ('Grand Slam Productions', 32.908414),
#  ('RT Features', 32.9059595),
#  ('Walden Media', 32.90146849999999),
#  ('Waverly Films', 32.8753295),
#  ('Marvel Knights', 32.867388),
#  ('Versus Entertainment', 32.841229),
#  ('Dark Trick Films', 32.841229),
#  ('The Ladd Company', 32.81296275),
#  ('RGB Media', 32.808675),
#  ('Filmf÷rderungsanstalt (FFA)', 32.80597933333333),
#  ('Olive Bridge Entertainment', 32.79742025),
#  ('Buckaroo Entertainment', 32.796246),
#  ('Spring Creek Productions', 32.7397838),
#  ('Tri-State Pictures', 32.717853),
#  ('Woods Entertainment', 32.6401195),
#  ("Bull's Eye Entertainment", 32.592058),
#  ('No Frills Film Production', 32.579697),
#  ('Turman-Foster Company', 32.5471275),
#  ('Bedford Falls Company, The', 32.533792),
#  ('Programme MEDIA de la CommunautT EuropTenne', 32.523573),
#  ('Mediaset', 32.523573),
#  ('Indigo Film', 32.523573),
#  ('Biscottificio Verona', 32.523573),
#  ('Banca Popolare di Vicenza', 32.523573),
#  ('Babe Films', 32.523573),
#  ('Les CinTmas de la Zone', 32.476098),
#  ('120 Films', 32.476098),
#  ('EOS Entertainment', 32.445895),
#  ('+sterreichischer Rundfunk (ORF)', 32.445895),
#  ('Nina Saxon Film Design', 32.4134375),
#  ('United Plankton Pictures', 32.411511499999996),
#  ('Dreamworks Pictures', 32.389353),
#  ('16 Block Productions', 32.31022),
#  ('Maple Shade Films', 32.271938),
#  ('Frantic Films', 32.271938),
#  ('Catwoman Films', 32.271938),
#  ('Brothers Dowdle Productions', 32.25877),
#  ('Y Productions', 32.243357),
#  ('Mediana Productions Filmgesellschaft', 32.243357),
#  ('Splendid Pictures', 32.243021000000006),
#  ('Mark Johnson Productions', 32.230981),
#  ('Motion Picture KAPPA Produktionsgesellschaft', 32.227223),
#  ('Horizon Pictures (II)', 32.1981475),
#  ('Mace Neufeld Productions', 32.184518600000004),
#  ('Mimran Schur Pictures', 32.1801005),
#  ('Windy Hill Pictures', 32.105328),
#  ('Salamander Pictures', 32.105328),
#  ('Pam Williams Productions', 32.105328),
#  ('Follow Through Productions', 32.105328),
#  ('Government of Malta', 32.1010015),
#  ('Marv Films', 32.069635875),
#  ('Oak Productions', 32.044191),
#  ('Vertigo Entertainment', 31.996769687500002),
#  ('Electric City Entertainment', 31.9826515),
#  ('Essential Media & Entertainment', 31.957947),
#  ('87Eleven', 31.92695),
#  ('Dune Entertainment III', 31.891568423076926),
#  ('Toff Guy Films', 31.887978),
#  ('Versßtil Cinema', 31.88251),
#  ('Onda Entertainment', 31.856589),
#  ('Pariah', 31.84699566666667),
#  ('Exclusive Media Group', 31.836104600000006),
#  ('Blinding Edge Pictures', 31.828118874999998),
#  ('Ombra Films', 31.771396000000003),
#  ('PIC Agency', 31.763201),
#  ('Lol Productions', 31.763201),
#  ('Open Road Films', 31.7598273),
#  ('Original Film', 31.75416036666667),
#  ('Wild Hogs Productions', 31.719463),
#  ...]

# %% [markdown]
# ### Question 10
#
# How many female actors (i.e. gender = 1) have a name that starts with the letter "N"?
#
#
# **Options:**
#
#  - 0
#  - 355
#  - 7335
#  - 1949

# %%
# %%sql
# SELECT
#     COUNT(actor_name)
#     -- gender
# FROM
#     actors
# WHERE
#     gender = 1 AND actor_name LIKE "N%"
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(355,)]

# %% [markdown]
# ### Question 11
#
# Which genre has, on average, the lowest movie popularity score?
#
#
# **Options:**
#
#  - Science Fiction
#  - Animation
#  - Documentary
#  - Foreign

# %%
# %%sql
# SELECT
#     *
# FROM
#     sqlite_master
# WHERE
#     type = "table"
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('table', 'actors', 'actors', 2, 'CREATE TABLE `actors` (\n  `actor_id` integer NOT NULL\n,  `actor_name` varchar(100) DEFAULT NULL\n,  `gender` integer DEFAULT NULL\n,  PRIMARY KEY (`actor_id`)\n)'),
#  ('table', 'casts', 'casts', 320, 'CREATE TABLE `casts` (\n  `movie_id` integer NOT NULL\n,  `actor_id` integer NOT NULL\n,  `characters` varchar(500) NOT NULL\n,  PRIMARY KEY (`movie_ ... (92 characters truncated) ... tor_id`) REFERENCES `actors` (`actor_id`)\n,  CONSTRAINT `FK__Casts__movie_id__6477ECF3` FOREIGN KEY (`movie_id`) REFERENCES `movies` (`movie_id`)\n)'),
#  ('table', 'genremap', 'genremap', 1903, 'CREATE TABLE `genremap` (\n  `movie_id` integer NOT NULL\n,  `genre_id` integer NOT NULL\n,  PRIMARY KEY (`movie_id`,`genre_id`)\n,  CONSTRAINT `FK__ ... (45 characters truncated) ... re_id`) REFERENCES `genres` (`genre_id`)\n,  CONSTRAINT `FK__GenreMap__movie___4D94879B` FOREIGN KEY (`movie_id`) REFERENCES `movies` (`movie_id`)\n)'),
#  ('table', 'genres', 'genres', 1982, 'CREATE TABLE `genres` (\n  `genre_id` integer NOT NULL\n,  `genre_name` varchar(50) DEFAULT NULL\n,  PRIMARY KEY (`genre_id`)\n)'),
#  ('table', 'keywordmap', 'keywordmap', 1983, 'CREATE TABLE `keywordmap` (\n  `movie_id` integer NOT NULL\n,  `keyword_id` integer NOT NULL\n,  PRIMARY KEY (`movie_id`,`keyword_id`)\n,  CONSTRAINT ... (57 characters truncated) ... d`) REFERENCES `keywords` (`keyword_id`)\n,  CONSTRAINT `FK__KeywordMa__movie__534D60F1` FOREIGN KEY (`movie_id`) REFERENCES `movies` (`movie_id`)\n)'),
#  ('table', 'keywords', 'keywords', 2234, 'CREATE TABLE `keywords` (\n  `keyword_id` integer NOT NULL\n,  `keyword_name` varchar(500) DEFAULT NULL\n,  PRIMARY KEY (`keyword_id`)\n)'),
#  ('table', 'languagemap', 'languagemap', 2283, 'CREATE TABLE `languagemap` (\n  `movie_id` integer NOT NULL\n,  `iso_639_1` char(2) NOT NULL\n,  PRIMARY KEY (`movie_id`,`iso_639_1`)\n,  CONSTRAINT  ... (55 characters truncated) ... 1`) REFERENCES `languages` (`iso_639_1`)\n,  CONSTRAINT `FK__LanguageM__movie__59063A47` FOREIGN KEY (`movie_id`) REFERENCES `movies` (`movie_id`)\n)'),
#  ('table', 'languages', 'languages', 2331, 'CREATE TABLE `languages` (\n  `iso_639_1` char(2) NOT NULL\n,  `language_name` varchar(50) DEFAULT NULL\n,  PRIMARY KEY (`iso_639_1`)\n)'),
#  ('table', 'movies', 'movies', 2333, 'CREATE TABLE `movies` (\n  `movie_id` integer NOT NULL\n,  `title` varchar(500) DEFAULT NULL\n,  `release_date` datetime(6) DEFAULT NULL\n,  `budget` ... (351 characters truncated) ... \n,  `tagline` varchar(500) DEFAULT NULL\n,  `vote_average` double DEFAULT NULL\n,  `vote_count` integer DEFAULT NULL\n,  PRIMARY KEY (`movie_id`)\n)'),
#  ('table', 'oscars', 'oscars', 2922, 'CREATE TABLE `oscars` (\n  `year` varchar(10) DEFAULT NULL\n,  `award` varchar(500) DEFAULT NULL\n,  `winner` varchar(10) DEFAULT NULL\n,  `name` varchar(500) DEFAULT NULL\n,  `film` varchar(500) DEFAULT NULL\n)'),
#  ('table', 'productioncompanies', 'productioncompanies', 3127, 'CREATE TABLE `productioncompanies` (\n  `production_company_id` integer NOT NULL\n,  `production_company_name` varchar(500) DEFAULT NULL\n,  PRIMARY KEY (`production_company_id`)\n)'),
#  ('table', 'productioncompanymap', 'productioncompanymap', 3163, 'CREATE TABLE `productioncompanymap` (\n  `movie_id` integer NOT NULL\n,  `production_company_id` integer NOT NULL\n,  PRIMARY KEY (`movie_id`,`produc ... (122 characters truncated) ... )\n,  CONSTRAINT `FK__Productio__produ__5FB337D6` FOREIGN KEY (`production_company_id`) REFERENCES `productioncompanies` (`production_company_id`)\n)'),
#  ('table', 'productioncountries', 'productioncountries', 3258, 'CREATE TABLE `productioncountries` (\n  `iso_3166_1` char(2) NOT NULL\n,  `production_country_name` varchar(50) DEFAULT NULL\n,  PRIMARY KEY (`iso_3166_1`)\n)'),
#  ('table', 'productioncountrymap', 'productioncountrymap', 3260, 'CREATE TABLE `productioncountrymap` (\n  `movie_id` integer DEFAULT NULL\n,  `iso_3166_1` char(2) DEFAULT NULL\n,  CONSTRAINT `FK__Productio__iso_3__ ... (44 characters truncated) ... CES `productioncountries` (`iso_3166_1`)\n,  CONSTRAINT `FK__Productio__movie__08B54D69` FOREIGN KEY (`movie_id`) REFERENCES `movies` (`movie_id`)\n)'),
#  ('table', 'sysdiagrams', 'sysdiagrams', 3281, 'CREATE TABLE `sysdiagrams` (\n  `name` varchar(160) NOT NULL\n,  `principal_id` integer NOT NULL\n,  `diagram_id` integer NOT NULL\n,  `version` integer DEFAULT NULL\n,  `definition` longblob\n,  PRIMARY KEY (`diagram_id`)\n,  UNIQUE (`principal_id`,`name`)\n)')]

# %%
# %%sql
# SELECT
#     genres.genre_name,
#     AVG(movies.popularity) AS avg_genre_popularity
# FROM
#     genres
# INNER JOIN genremap ON genres.genre_id = genremap.genre_id
# INNER JOIN movies ON genremap.movie_id = movies.movie_id
# GROUP BY genres.genre_name
# ORDER BY avg_genre_popularity ASC
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('Foreign', 0.686786794117647),
#  ('Documentary', 3.945723809090908),
#  ('TV Movie', 6.389414749999999),
#  ('Music', 13.101512475675676),
#  ('Romance', 15.962426457494416),
#  ('History', 17.444838720812175),
#  ('Drama', 17.764853371789304),
#  ('Comedy', 18.221000988966285),
#  ('Western', 18.23627854878048),
#  ('Horror', 18.295915104046244),
#  ('Crime', 22.85327434051726),
#  ('War', 23.777288569444423),
#  ('Thriller', 24.460076525117703),
#  ('Mystery', 24.58682736494254),
#  ('Family', 27.832848912280713),
#  ('Action', 30.94038215337952),
#  ('Fantasy', 36.38704340094338),
#  ('Science Fiction', 36.45180587102805),
#  ('Animation', 38.81343931196578),
#  ('Adventure', 39.26804199113923)]

# %% [markdown]
# ### Question 12
#
# Which award category has the highest number of actor nominations (actors can be male or female)? (Hint: `Oscars.name` contains both actors' names and film names.)
#
# **Options:**
#
# - Special Achievement Award
# - Actor in a Supporting Role
# - Actress in a Supporting Role
# - Best Picture

# %%
# %%sql
# SELECT
#     oscars.award,
#     COUNT(oscars.name) AS no_of_actors
#     /*actors.actor_name,
#     oscars.name,
#     */
# FROM
#     actors
# LEFT JOIN
#     oscars ON actors.actor_name = oscars.name
# WHERE oscars.name NOT NULL
# GROUP BY oscars.award
# ORDER BY no_of_actors DESC
# -- LIMIT 300;
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('Actor in a Supporting Role', 356),
#  ('Actress in a Supporting Role', 331),
#  ('Actress in a Leading Role', 198),
#  ('Actor in a Leading Role', 197),
#  ('Actor', 184),
#  ('Actress', 145),
#  ('Honorary Award', 35),
#  ('Jean Hersholt Humanitarian Award', 15),
#  ('Special Award', 14),
#  ('Irving G. Thalberg Memorial Award', 12),
#  ('Directing', 4),
#  ('Special Achievement Award', 2),
#  ('Directing (Dramatic Picture)', 2),
#  ('John A. Bonner Medal of Commendation', 1),
#  ('Gordon E. Sawyer Award', 1),
#  ('Cinematography', 1)]

# %% [markdown]
# ### Question 13
#
# For all of the entries in the Oscars table before 1934, the year is stored differently than in all the subsequent years. For example, the year would be saved as “1932/1933” instead of just “1933” (the second indicated year).  Which of the following options would be the appropriate code to update this column to have the format of the year be consistent throughout the entire table (second indicated year only shown)?
#
#
# **Options:**
#
# - `UPDATE Oscars SET year = RIGHT(year, -4)`
# - `UPDATE Oscars SET year = SELECT substr(year, -4)`
# - `UPDATE Oscars SET year = substr(year, -4)`
# - `UPDATE Oscars year =  substr(year, 4)`

# %%
# %%sql
# SELECT
#     name,
#     year,
#     substr(year, -4) AS updated_year
# FROM
#     Oscars
# LIMIT 10;
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('Richard Barthelmess', '1928', '1928'),
#  ('Emil Jannings', '1928', '1928'),
#  ('Louise Dresser', '1928', '1928'),
#  ('Janet Gaynor', '1928', '1928'),
#  ('Gloria Swanson', '1928', '1928'),
#  ('Rochus Gliese', '1928', '1928'),
#  ('William Cameron Menzies', '1928', '1928'),
#  ('Harry Oliver', '1928', '1928'),
#  ('George Barnes', '1928', '1928'),
#  ('Charles Rosher', '1928', '1928')]

# %% [markdown]
# ### Question 14
#
# DStv will be having a special week dedicated to the actor Alan Rickman. Which of the following queries would create a new _view_ that shows the titles, release dates, taglines, and overviews of all movies that Alan Rickman has played in?
#
#
#
# **Options:**
#
# - SELECT title, release_date, tagline, overview
# FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
# AS VIEW Alan_Rickman_Movies
#
# - CREATE VIEW Alan_Rickman_Movies AS
# SELECT title, release_date, tagline, overview FROM Movies
# LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors
# ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
#
#
# - CREATE NEW VIEW  Name  = Alan_Rickman_Movies AS SELECT title, release_date, tagline, overview FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'
#
# - VIEW Alan_Rickman_Movies AS SELECT title, release_date, tagline, overview FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'

# %%
# %%sql
# SELECT
#     title,
#     release_date,
#     tagline,
#     actors.actor_name,
#     overview
# FROM
#     Movies
# LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id
# Left JOIN Actors ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('Love Actually', '2003-09-07 00:00:00.000000', 'The ultimate romantic comedy.', 'Alan Rickman', 'Follows seemingly unrelated people as their lives begin to intertwine while they fall in û and out û of love. Affections languish and develop as Christmas draws near.'),
#  ('Die Hard', '1988-07-15 00:00:00.000000', '40 Stories. Twelve Terrorists. One Cop.', 'Alan Rickman', "NYPD cop, John McClane's plan to reconcile with his estranged wife is thrown for a serious loop when minutes after he arrives at her office, the enti ... (31 characters truncated) ... roup of terrorists. With little help from the LAPD, wisecracking McClane sets out to single-handedly rescue the hostages and bring the bad guys down."),
#  ("Harry Potter and the Philosopher's Stone", '2001-11-16 00:00:00.000000', 'Let the Magic Begin.', 'Alan Rickman', "Harry Potter has lived under the stairs at his aunt and uncle's house his whole life. But on his 11th birthday, he learns he's a powerful wizard -- w ... (114 characters truncated) ... d powers with the help of the school's kindly headmaster, Harry uncovers the truth about his parents' deaths -- and about the villain who's to blame."),
#  ('Harry Potter and the Chamber of Secrets', '2002-11-13 00:00:00.000000', 'Hogwarts is back in session.', 'Alan Rickman', 'Ignoring threats to his life, Harry returns to Hogwarts to investigate û aided by Ron and Hermione û a mysterious series of attacks.'),
#  ('Harry Potter and the Prisoner of Azkaban', '2004-05-31 00:00:00.000000', 'Something wicked this way comes.', 'Alan Rickman', 'Harry, Ron and Hermione return to Hogwarts for another magic-filled year. Harry comes face to face with danger yet again, this time in the form of escaped convict, Sirius Black û and turns to sympathetic Professor Lupin for help.'),
#  ('Harry Potter and the Goblet of Fire', '2005-11-05 00:00:00.000000', 'Dark And Difficult Times Lie Ahead.', 'Alan Rickman', 'Harry starts his fourth year at Hogwarts, competes in the treacherous Triwizard Tournament and faces the evil Lord Voldemort. Ron and Hermione help Harry manage the pressure û but Voldemort lurks, awaiting his chance to destroy Harry and all that he stands for.'),
#  ('Harry Potter and the Order of the Phoenix', '2007-06-28 00:00:00.000000', 'Evil Must Be Confronted.', 'Alan Rickman', "Returning for his fifth year of study at Hogwarts, Harry is stunned to find that his warnings about the return of Lord Voldemort have been ignored. L ... (20 characters truncated) ... Harry takes matters into his own hands, training a small group of students û dubbed 'Dumbledore's Army' û to defend themselves against the dark arts."),
#  ('Harry Potter and the Half-Blood Prince', '2009-07-07 00:00:00.000000', 'Dark Secrets Revealed', 'Alan Rickman', "As Harry begins his sixth year at Hogwarts, he discovers an old book marked as 'Property of the Half-Blood Prince', and begins to learn more about Lord Voldemort's dark past."),
#  ('Galaxy Quest', '1999-12-23 00:00:00.000000', 'A comedy of Galactic Proportions.', 'Alan Rickman', "The stars of a 1970s sci-fi show - now scraping a living through re-runs and sci-fi conventions - are beamed aboard an alien spacecraft. Believing th ... (64 characters truncated) ... l-life adventures, the band of aliens turn to the ailing celebrities for help in their quest to overcome the oppressive regime in their solar system."),
#  ('Perfume: The Story of a Murderer', '2006-09-13 00:00:00.000000', 'Based on the best-selling novel', 'Alan Rickman', "Jean-Baptiste Grenouille, born in the stench of 18th century Paris, develops a superior olfactory sense, which he uses to create the world's finest perfumes. However, his work takes a dark turn as he tries to preserve scents in the search for the ultimate perfume."),
#  ('Michael Collins', '1996-10-25 00:00:00.000000', "Ireland, 1916. His Dreams Inspired Hope. His Words Ignited Passion. His Courage Forged A Nation's Destiny.", 'Alan Rickman', 'Michael Collins plays a crucial role in the establishment of the Irish Free State in the 1920s, but becomes vilified by those hoping to create a completely independent Irish republic.'),
#  ('Dogma', '1999-11-12 00:00:00.000000', 'It can be Hell getting into Heaven', 'Alan Rickman', 'The latest battle in the eternal war between Good and Evil has come to New Jersey in the late, late 20th Century. Angels, demons, apostles and prophets (of a sort) walk among the cynics and innocents of America and duke it out for the fate of humankind.'),
#  ('Sense and Sensibility', '1995-12-13 00:00:00.000000', 'Lose your heart and come to your senses.', 'Alan Rickman', 'Rich Mr. Dashwood dies, leaving his second wife and her daughters poor by the rules of inheritance. Two daughters are the titular opposites.'),
#  ("The Hitchhiker's Guide to the Galaxy", '2005-01-15 00:00:00.000000', "Don't leave Earth without it.", 'Alan Rickman', '"Mere seconds before the Earth is to be demolished by an alien construction crew, Arthur Dent is swept off the planet by his friend Ford Prefect, a researcher penning a new edition of ""The Hitchhiker\'s Guide to the Galaxy."""'),
#  ('Robin Hood: Prince of Thieves', '1991-06-14 00:00:00.000000', 'For the good of all men, and the love of one woman, he fought to uphold justice by breaking the law.', 'Alan Rickman', "When the dastardly Sheriff of Nottingham murders Robin's father, the legendary archer vows vengeance. To accomplish his mission, Robin joins forces with a band of exiled villagers (and comely Maid Marian), and together they battle to end the evil sheriff's reign of terror."),
#  ('Quigley Down Under', '1990-10-17 00:00:00.000000', "There's a price on his head. A girl on his mind. And a twinkle in his eye.", 'Alan Rickman', "American Matt Quigley answers Australian land baron Elliott Marston's ad for a sharpshooter to kill the dingoes on his property. But when Quigley fin ... (45 characters truncated) ... igines, Quigley hits the road. Now, even American expatriate Crazy Cora can't keep Quigley safe in his cat-and-mouse game with the homicidal Marston."),
#  ('Alice in Wonderland', '2010-03-03 00:00:00.000000', "You're invited to a very important date.", 'Alan Rickman', "Alice, an unpretentious and individual 19-year-old, is betrothed to a dunce of an English nobleman. At her engagement party, she escapes the crowd to ... (328 characters truncated) ... ous bandersnatches. Alice realizes that she is there for a reason û to conquer the horrific Jabberwocky and restore the rightful queen to her throne."),
#  ('Bottle Shock', '2008-08-06 00:00:00.000000', 'Based on a true story of love, victory, and fermentation', 'Alan Rickman', 'Paris-based wine expert Steven Spurrier heads to California in search of cheap wine that he can use for a blind taste test in the French capital. Stu ... (55 characters truncated) ...  shocked to discover a winery turning out top-notch chardonnay. Determined to make a name for himself, he sets about getting the booze back to Paris.'),
#  ('The Butler', '2013-08-16 00:00:00.000000', 'One quiet voice can ignite a revolution.', 'Alan Rickman', "A look at the life of Cecil Gaines who served eight presidents as the White House's head butler from 1952 to 1986, and had a unique front-row seat as political and racial history was made."),
#  ('Alice Through the Looking Glass', '2016-05-25 00:00:00.000000', "It's time for a little madness.", 'Alan Rickman', '"In the sequel to Tim Burton\'s ""Alice in Wonderland"", Alice Kingsleigh returns to Underland and faces a new adventure in saving the Mad Hatter."')]

# %% [markdown]
# ### Question 15
#
# Which of the statements about database normalisation are true?
#
# **Statements:**
#
# i) Database normalisation improves data redundancy, saves on storage space, and fulfils the requirement of records to be uniquely identified.
#
# ii) Database normalisation supports up to the Third Normal Form and removes all data anomalies.
#
# iii) Database normalisation removes inconsistencies that may cause the analysis of our data to be more complicated.
#
# iv) Database normalisation increases data redundancy, saves on storage space, and fulfils the requirement of records to be uniquely identified.
#
# **Options:**
#
#  - (i) and (ii)
#  - (i) and (iii)
#  - (ii) and (iv)
#  - (iii) and (iv)

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
